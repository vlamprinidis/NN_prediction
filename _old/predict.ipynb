# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from profiling.funs import load, numf_ls, batch_ls, hp_map

# %%
def corr(df, feat, title):
    plt.scatter(df[feat], df['total_ms'])
    plt.title(title, fontsize=14)
    plt.xlabel(feat, fontsize=14)
    plt.ylabel('total_ms', fontsize=14)
    plt.grid(True)
    plt.show()

def plot_numf(df_big, layer):
    df = df_big[df_big['model_str']==layer]
    for nodes in [1,2,3]:
        for batch in batch_ls:
            for hp in hp_map[layer]:
                mask = (df['batch']==batch) & (df['hp']==hp) & (df['nodes']==nodes)
                title = '{}, nodes: {}, batch: {}, hp: {}'.format(layer, nodes, batch, hp)
                
                corr(df[mask], 'numf', title)


def plot_batch(df_big, layer):
    df = df_big[df_big['model_str']==layer]
    for nodes in [1,2,3]:
        for numf in numf_ls:
            for hp in hp_map[layer]:
                mask = (df.nodes==nodes)&(df.numf==numf)&(df.hp==hp)
                title = '{}, nodes: {}, numf: {}, hp: {}'.format(layer, nodes, numf, hp)
                
                corr(df[mask], 'batch', title)                

def plot_nodes(df_big, layer):
    df = df_big[df_big['model_str']==layer]
    for numf in numf_ls:
        for batch in batch_ls:
            for hp in hp_map[layer]:
                mask = (df.numf==numf)&(df.batch==batch)&(df.hp==hp)
                title = '{}, numf: {}, batch: {}, hp: {}'.format(layer, numf, batch, hp)
                
                corr(df[mask], 'nodes', title)

def plot_hp(df_big, layer):
    df = df_big[df_big['model_str']==layer]
    for nodes in [1,2,3]:
        for numf in numf_ls:
            for batch in batch_ls:
                mask = (df.nodes==nodes)&(df.numf==numf)&(df.batch==batch)
                title = '{}, nodes: {}, numf: {}, batch: {}'.format(layer, nodes, numf, batch)
                
                corr(df[mask], 'hp', title)
    
def plot(df, layer, feat):
    mask = df['model_str']==layer
    title = '{}, {}'.format(layer, feat)
    corr(df[mask], feat, title)

# %%
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
def give_train_data(df, layer):
    mask = df['model_str'] == layer
    df_ = df[mask].drop(columns='model_str')
    
    return df_.drop(columns='total_ms').to_numpy(), df_.total_ms.to_numpy()

def the_train(df, model, layer):
    x,y = give_train_data(df, layer)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
    model.fit(x_train, y_train)
    score = model.score(x_test, y_test)
    print('Model: {}, Layer: {}, Score: {}'.format(model, layer, score))
    print()
    
    return model

# %%
layers = ['conv1d', 'conv2d', 'avg1d', 'avg2d', 'max1d', 'max2d', 'dense', 'norm1d', 'norm2d']

# %%
models = {
    'linear': LinearRegression(),
    'ridge': Ridge(),
    'lasso': Lasso(),
    'elastic': ElasticNet(),
    'kneighbors': KNeighborsRegressor(),
    'tree': DecisionTreeRegressor(),
    'svr': SVR(),
    'forest': RandomForestRegressor(),
}

# %%
def _all(df):
    for key in models:
        for layer in layers:
            the_train(df, models[key], layer)
        print('---')
        print()

# %%
file = 'datasets/total_{}.{}'.format

# %%
big_file = 'datasets/big_total_{}.{}'.format

# %%
tf = pd.concat([load(file(num, 'tflow')) for num in [1,2,3]], ignore_index=True)

_all(tf)
# Out:
# Model: LinearRegression(), Layer: conv1d, Score: 0.7772487941059837
#
# Model: LinearRegression(), Layer: conv2d, Score: 0.7839840267344762
#
# Model: LinearRegression(), Layer: avg1d, Score: 0.7574135524549175
#
# Model: LinearRegression(), Layer: avg2d, Score: 0.8732096143059664
#
# Model: LinearRegression(), Layer: max1d, Score: 0.7825804134737229
#
# Model: LinearRegression(), Layer: max2d, Score: 0.8551001651697762
#
# Model: LinearRegression(), Layer: dense, Score: 0.43654498673357434
#
# Model: LinearRegression(), Layer: norm1d, Score: 0.7828810710234306
#
# Model: LinearRegression(), Layer: norm2d, Score: 0.8744675432824315
#
# ---
#
# Model: Ridge(), Layer: conv1d, Score: 0.756847358004004
#
# Model: Ridge(), Layer: conv2d, Score: 0.7750954669402718
#
# Model: Ridge(), Layer: avg1d, Score: 0.04053371894419877
#
# Model: Ridge(), Layer: avg2d, Score: 0.8834048033129278
#
# Model: Ridge(), Layer: max1d, Score: 0.7554949248542873
#
# Model: Ridge(), Layer: max2d, Score: 0.8855865549849123
#
# Model: Ridge(), Layer: dense, Score: 0.24542696479494763
#
# Model: Ridge(), Layer: norm1d, Score: 0.7033610305887739
#
# Model: Ridge(), Layer: norm2d, Score: 0.8808495674757322
#
# ---
#
# Model: Lasso(), Layer: conv1d, Score: 0.6871246788844776
#
# Model: Lasso(), Layer: conv2d, Score: 0.7326831436811394
#
# Model: Lasso(), Layer: avg1d, Score: 0.5677282470783251
#
# Model: Lasso(), Layer: avg2d, Score: 0.9198015018933011
#
# Model: Lasso(), Layer: max1d, Score: 0.7195033757582284
#
# Model: Lasso(), Layer: max2d, Score: 0.8725640935007221
#
# Model: Lasso(), Layer: dense, Score: 0.40873439579011495
#
# Model: Lasso(), Layer: norm1d, Score: 0.5725585140145437
#
# Model: Lasso(), Layer: norm2d, Score: 0.8656174412170854
#
# ---
#
# Model: ElasticNet(), Layer: conv1d, Score: 0.5728857558616767
#
# Model: ElasticNet(), Layer: conv2d, Score: 0.8227773239572753
#
# Model: ElasticNet(), Layer: avg1d, Score: 0.602366970790361
#
# Model: ElasticNet(), Layer: avg2d, Score: 0.8809388869808973
#
# Model: ElasticNet(), Layer: max1d, Score: 0.5914388341698168
#
# Model: ElasticNet(), Layer: max2d, Score: 0.8885496665253321
#
# Model: ElasticNet(), Layer: dense, Score: 0.3306548327569383
#
# Model: ElasticNet(), Layer: norm1d, Score: 0.6431134487414885
#
# Model: ElasticNet(), Layer: norm2d, Score: 0.8158283813938686
#
# ---
#
# Model: KNeighborsRegressor(), Layer: conv1d, Score: 0.22209637589972853
#
# Model: KNeighborsRegressor(), Layer: conv2d, Score: 0.9581424386088604
#
# Model: KNeighborsRegressor(), Layer: avg1d, Score: -0.008622804486234648
#
# Model: KNeighborsRegressor(), Layer: avg2d, Score: 0.8762265997915583
#
# Model: KNeighborsRegressor(), Layer: max1d, Score: 0.15989093200433147
#
# Model: KNeighborsRegressor(), Layer: max2d, Score: 0.8807512799626022
#
# Model: KNeighborsRegressor(), Layer: dense, Score: 0.9989895339992388
#
# Model: KNeighborsRegressor(), Layer: norm1d, Score: 0.26869343374478005
#
# Model: KNeighborsRegressor(), Layer: norm2d, Score: 0.8695380638751405
#
# ---
#
# Model: DecisionTreeRegressor(), Layer: conv1d, Score: 0.9678513624393501
#
# Model: DecisionTreeRegressor(), Layer: conv2d, Score: 0.9973347550460453
#
# Model: DecisionTreeRegressor(), Layer: avg1d, Score: 0.9635554171078805
#
# Model: DecisionTreeRegressor(), Layer: avg2d, Score: 0.9470129107716204
#
# Model: DecisionTreeRegressor(), Layer: max1d, Score: 0.983930384415051
#
# Model: DecisionTreeRegressor(), Layer: max2d, Score: 0.9878086046706451
#
# Model: DecisionTreeRegressor(), Layer: dense, Score: 0.9975685302855075
#
# Model: DecisionTreeRegressor(), Layer: norm1d, Score: 0.982330063326988
#
# Model: DecisionTreeRegressor(), Layer: norm2d, Score: 0.9977121337775828
#
# ---
#
# Model: SVR(), Layer: conv1d, Score: -0.012293264111757018
#
# Model: SVR(), Layer: conv2d, Score: -0.24396804616084466
#
# Model: SVR(), Layer: avg1d, Score: -0.11504826493726861
#
# Model: SVR(), Layer: avg2d, Score: -0.16350216533623874
#
# Model: SVR(), Layer: max1d, Score: -0.200007153575388
#
# Model: SVR(), Layer: max2d, Score: -0.34541411597951654
#
# Model: SVR(), Layer: dense, Score: -0.13838911704084533
#
# Model: SVR(), Layer: norm1d, Score: -0.5295187016230494
#
# Model: SVR(), Layer: norm2d, Score: -0.19866116533280764
#
# ---
#
# Model: RandomForestRegressor(), Layer: conv1d, Score: 0.9719672196470587
#
# Model: RandomForestRegressor(), Layer: conv2d, Score: 0.998736244169148
#
# Model: RandomForestRegressor(), Layer: avg1d, Score: 0.9748327933346611
#
# Model: RandomForestRegressor(), Layer: avg2d, Score: 0.9965170734582894
#
# Model: RandomForestRegressor(), Layer: max1d, Score: 0.9842067348000965
#
# Model: RandomForestRegressor(), Layer: max2d, Score: 0.9942784685205304
#
# Model: RandomForestRegressor(), Layer: dense, Score: 0.9994679169383295
#
# Model: RandomForestRegressor(), Layer: norm1d, Score: 0.9870451679114166
#
# Model: RandomForestRegressor(), Layer: norm2d, Score: 0.995771796683225
#
# ---

# %%
tor = pd.concat([load(file(num, 'torch')) for num in [1,2,3]], ignore_index=True)

_all(tor)
# Out:
# Model: LinearRegression(), Layer: conv1d, Score: 0.3387087583807057
#
# Model: LinearRegression(), Layer: conv2d, Score: 0.6175166185879135
#
# Model: LinearRegression(), Layer: avg1d, Score: 0.27309818697679333
#
# Model: LinearRegression(), Layer: avg2d, Score: 0.607886958324281
#
# Model: LinearRegression(), Layer: max1d, Score: 0.6377647304952963
#
# Model: LinearRegression(), Layer: max2d, Score: 0.47356573154212356
#
# Model: LinearRegression(), Layer: dense, Score: 0.714647795738949
#
# Model: LinearRegression(), Layer: norm1d, Score: 0.12489961455775234
#
# Model: LinearRegression(), Layer: norm2d, Score: 0.6109827241670107
#
# ---
#
# Model: Ridge(), Layer: conv1d, Score: 0.44319123388085147
#
# Model: Ridge(), Layer: conv2d, Score: 0.5566129210437853
#
# Model: Ridge(), Layer: avg1d, Score: 0.35995188359708064
#
# Model: Ridge(), Layer: avg2d, Score: 0.4980966004349069
#
# Model: Ridge(), Layer: max1d, Score: 0.650505008300308
#
# Model: Ridge(), Layer: max2d, Score: 0.46055225612255934
#
# Model: Ridge(), Layer: dense, Score: 0.6133667329951032
#
# Model: Ridge(), Layer: norm1d, Score: 0.09405437702204844
#
# Model: Ridge(), Layer: norm2d, Score: 0.6692497989723658
#
# ---
#
# Model: Lasso(), Layer: conv1d, Score: 0.04812076754833239
#
# Model: Lasso(), Layer: conv2d, Score: 0.5006569843867743
#
# Model: Lasso(), Layer: avg1d, Score: 0.07479759454992863
#
# Model: Lasso(), Layer: avg2d, Score: 0.6841194659399996
#
# Model: Lasso(), Layer: max1d, Score: 0.5484257152992142
#
# Model: Lasso(), Layer: max2d, Score: 0.6150575765776899
#
# Model: Lasso(), Layer: dense, Score: 0.6140803330658535
#
# Model: Lasso(), Layer: norm1d, Score: 0.5285410469431371
#
# Model: Lasso(), Layer: norm2d, Score: 0.6023798730223605
#
# ---
#
# Model: ElasticNet(), Layer: conv1d, Score: 0.2036424284736883
#
# Model: ElasticNet(), Layer: conv2d, Score: 0.5932187278927257
#
# Model: ElasticNet(), Layer: avg1d, Score: 0.20713413047348384
#
# Model: ElasticNet(), Layer: avg2d, Score: 0.6007638550019612
#
# Model: ElasticNet(), Layer: max1d, Score: 0.6130308612799111
#
# Model: ElasticNet(), Layer: max2d, Score: 0.6156720159919468
#
# Model: ElasticNet(), Layer: dense, Score: 0.5920458414059155
#
# Model: ElasticNet(), Layer: norm1d, Score: 0.8745041262986277
#
# Model: ElasticNet(), Layer: norm2d, Score: 0.5423705222230886
#
# ---
#
# Model: KNeighborsRegressor(), Layer: conv1d, Score: 0.27211041981067785
#
# Model: KNeighborsRegressor(), Layer: conv2d, Score: 0.9894816948435675
#
# Model: KNeighborsRegressor(), Layer: avg1d, Score: 0.33325672004029905
#
# Model: KNeighborsRegressor(), Layer: avg2d, Score: 0.9814458339929222
#
# Model: KNeighborsRegressor(), Layer: max1d, Score: 0.7321654315769797
#
# Model: KNeighborsRegressor(), Layer: max2d, Score: 0.9803522002709506
#
# Model: KNeighborsRegressor(), Layer: dense, Score: 0.9333243319670412
#
# Model: KNeighborsRegressor(), Layer: norm1d, Score: 0.7847716841409381
#
# Model: KNeighborsRegressor(), Layer: norm2d, Score: 0.9948268231382409
#
# ---
#
# Model: DecisionTreeRegressor(), Layer: conv1d, Score: 0.17973002620885703
#
# Model: DecisionTreeRegressor(), Layer: conv2d, Score: 0.998149984053137
#
# Model: DecisionTreeRegressor(), Layer: avg1d, Score: 0.5743856491726241
#
# Model: DecisionTreeRegressor(), Layer: avg2d, Score: 0.9893753175723236
#
# Model: DecisionTreeRegressor(), Layer: max1d, Score: 0.7295676972667142
#
# Model: DecisionTreeRegressor(), Layer: max2d, Score: 0.9990701550802096
#
# Model: DecisionTreeRegressor(), Layer: dense, Score: 0.9594412234550286
#
# Model: DecisionTreeRegressor(), Layer: norm1d, Score: 0.9329896340975354
#
# Model: DecisionTreeRegressor(), Layer: norm2d, Score: 0.9951265962723027
#
# ---
#
# Model: SVR(), Layer: conv1d, Score: 0.3313721631898179
#
# Model: SVR(), Layer: conv2d, Score: 0.06998934347116392
#
# Model: SVR(), Layer: avg1d, Score: 0.313930090235521
#
# Model: SVR(), Layer: avg2d, Score: 0.1714841441562226
#
# Model: SVR(), Layer: max1d, Score: 0.5653050262868949
#
# Model: SVR(), Layer: max2d, Score: 0.10067224808947228
#
# Model: SVR(), Layer: dense, Score: 0.6598390669254386
#
# Model: SVR(), Layer: norm1d, Score: 0.9006636837032563
#
# Model: SVR(), Layer: norm2d, Score: -0.0746951332798993
#
# ---
#
# Model: RandomForestRegressor(), Layer: conv1d, Score: -0.18626676373491224
#
# Model: RandomForestRegressor(), Layer: conv2d, Score: 0.9986918494892503
#
# Model: RandomForestRegressor(), Layer: avg1d, Score: 0.5858102014651192
#
# Model: RandomForestRegressor(), Layer: avg2d, Score: 0.991400992185208
#
# Model: RandomForestRegressor(), Layer: max1d, Score: 0.6457932802400455
#
# Model: RandomForestRegressor(), Layer: max2d, Score: 0.9938525544931507
#
# Model: RandomForestRegressor(), Layer: dense, Score: 0.9794208274307991
#
# Model: RandomForestRegressor(), Layer: norm1d, Score: 0.9095263670449524
#
# Model: RandomForestRegressor(), Layer: norm2d, Score: 0.9951883197756352
#
# ---

# %%
tor=load(file(1, 'torch'))

# %%
plot_batch(tor, 'max1d')

# %%
plot_nodes(tor, 'max1d')

# %%
plot_numf(tor, 'max1d')

# %%
plot_hp(tor, 'max1d')

# %%
plot(tor, 'max1d', 'batch')
plot(tor, 'max1d', 'nodes')
plot(tor, 'max1d', 'numf')
plot(tor, 'max1d', 'hp')

# %%
tor = pd.concat([load(big_file(num, 'torch')) for num in [1,2,3]], ignore_index=True)

_all(tor)
# Out:
# Model: LinearRegression(), Layer: conv1d, Score: 0.14597624714878854
#
# Model: LinearRegression(), Layer: conv2d, Score: 0.2817024107701914
#
# Model: LinearRegression(), Layer: avg1d, Score: 0.8001910109165916
#
# Model: LinearRegression(), Layer: avg2d, Score: 0.6527923081578368
#
# Model: LinearRegression(), Layer: max1d, Score: 0.8531889601543609
#
# Model: LinearRegression(), Layer: max2d, Score: 0.5528392481302953
#
# Model: LinearRegression(), Layer: dense, Score: 0.6905793708468
#
# Model: LinearRegression(), Layer: norm1d, Score: 0.859305645868675
#
# Model: LinearRegression(), Layer: norm2d, Score: 0.6154741000236481
#
# ---
#
# Model: Ridge(), Layer: conv1d, Score: 0.7174413690490633
#
# Model: Ridge(), Layer: conv2d, Score: 0.545385569777461
#
# Model: Ridge(), Layer: avg1d, Score: 0.050962059096967605
#
# Model: Ridge(), Layer: avg2d, Score: 0.5267616674307232
#
# Model: Ridge(), Layer: max1d, Score: 0.8588766422872576
#
# Model: Ridge(), Layer: max2d, Score: 0.6122812899944766
#
# Model: Ridge(), Layer: dense, Score: 0.5399441348151481
#
# Model: Ridge(), Layer: norm1d, Score: 0.8750071050460989
#
# Model: Ridge(), Layer: norm2d, Score: 0.5749172134320522
#
# ---
#
# Model: Lasso(), Layer: conv1d, Score: 0.6432773917103098
#
# Model: Lasso(), Layer: conv2d, Score: 0.6179841567120873
#
# Model: Lasso(), Layer: avg1d, Score: 0.7289094029918413
#
# Model: Lasso(), Layer: avg2d, Score: 0.5860743561585875
#
# Model: Lasso(), Layer: max1d, Score: 0.7206464325437807
#
# Model: Lasso(), Layer: max2d, Score: 0.6275484634665547
#
# Model: Lasso(), Layer: dense, Score: 0.6390880159739893
#
# Model: Lasso(), Layer: norm1d, Score: 0.8602151646452382
#
# Model: Lasso(), Layer: norm2d, Score: 0.6403695221462287
#
# ---
#
# Model: ElasticNet(), Layer: conv1d, Score: 0.5491944774774677
#
# Model: ElasticNet(), Layer: conv2d, Score: 0.5997252986878301
#
# Model: ElasticNet(), Layer: avg1d, Score: 0.007923423810672459
#
# Model: ElasticNet(), Layer: avg2d, Score: 0.6520273479905833
#
# Model: ElasticNet(), Layer: max1d, Score: 0.833689994539984
#
# Model: ElasticNet(), Layer: max2d, Score: 0.5860012879353451
#
# Model: ElasticNet(), Layer: dense, Score: 0.5965849722393779
#
# Model: ElasticNet(), Layer: norm1d, Score: 0.8273458072005738
#
# Model: ElasticNet(), Layer: norm2d, Score: 0.6632148816715875
#
# ---
#
# Model: KNeighborsRegressor(), Layer: conv1d, Score: 0.12668662410856757
#
# Model: KNeighborsRegressor(), Layer: conv2d, Score: 0.9899162837072766
#
# Model: KNeighborsRegressor(), Layer: avg1d, Score: 0.02434593065617252
#
# Model: KNeighborsRegressor(), Layer: avg2d, Score: 0.9662676361847832
#
# Model: KNeighborsRegressor(), Layer: max1d, Score: 0.811527997347426
#
# Model: KNeighborsRegressor(), Layer: max2d, Score: 0.9821775783450976
#
# Model: KNeighborsRegressor(), Layer: dense, Score: 0.9418434157028674
#
# Model: KNeighborsRegressor(), Layer: norm1d, Score: 0.87117177286269
#
# Model: KNeighborsRegressor(), Layer: norm2d, Score: 0.9949110167964406
#
# ---
#
# Model: DecisionTreeRegressor(), Layer: conv1d, Score: 0.6015394357934425
#
# Model: DecisionTreeRegressor(), Layer: conv2d, Score: 0.9992831766693119
#
# Model: DecisionTreeRegressor(), Layer: avg1d, Score: -1.4367578713597875
#
# Model: DecisionTreeRegressor(), Layer: avg2d, Score: 0.9857939316274497
#
# Model: DecisionTreeRegressor(), Layer: max1d, Score: 0.7387943530284531
#
# Model: DecisionTreeRegressor(), Layer: max2d, Score: 0.998861275083235
#
# Model: DecisionTreeRegressor(), Layer: dense, Score: 0.972623515085984
#
# Model: DecisionTreeRegressor(), Layer: norm1d, Score: 0.8114388195949634
#
# Model: DecisionTreeRegressor(), Layer: norm2d, Score: 0.9979099796223116
#
# ---
#
# Model: SVR(), Layer: conv1d, Score: 0.0578464194715117
#
# Model: SVR(), Layer: conv2d, Score: -0.1266767410223688
#
# Model: SVR(), Layer: avg1d, Score: 0.7514721236133597
#
# Model: SVR(), Layer: avg2d, Score: 0.1288925015273067
#
# Model: SVR(), Layer: max1d, Score: 0.7490169100669032
#
# Model: SVR(), Layer: max2d, Score: 0.11711857303125062
#
# Model: SVR(), Layer: dense, Score: 0.5378540542931292
#
# Model: SVR(), Layer: norm1d, Score: 0.7638820194109203
#
# Model: SVR(), Layer: norm2d, Score: -0.11331192873645923
#
# ---
#
# Model: RandomForestRegressor(), Layer: conv1d, Score: 0.7748573447184499
#
# Model: RandomForestRegressor(), Layer: conv2d, Score: 0.9981565522549808
#
# Model: RandomForestRegressor(), Layer: avg1d, Score: 0.5026376729603816
#
# Model: RandomForestRegressor(), Layer: avg2d, Score: 0.9903775744585953
#
# Model: RandomForestRegressor(), Layer: max1d, Score: 0.8398429690924469
#
# Model: RandomForestRegressor(), Layer: max2d, Score: 0.9975941818082443
#
# Model: RandomForestRegressor(), Layer: dense, Score: 0.9660331562223134
#
# Model: RandomForestRegressor(), Layer: norm1d, Score: 0.9558508380986558
#
# Model: RandomForestRegressor(), Layer: norm2d, Score: 0.9982869893953554
#
# ---
