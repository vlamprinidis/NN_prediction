# %%
from profiling.funs import load
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
tor = load('profiling/results/data_1.torch')

# %%
for key in tor:
    print(key)
    break

# %%
key = frozenset({('model_str', 'avg1d'), ('batch', 64), ('hp', 4), ('nodes', 3), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'max1d'), ('batch', 512), ('hp', 4), ('nodes', 2), ('numf', 128)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'max2d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'conv1d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'conv2d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'dense'), ('batch', 64), ('hp', 32), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'norm1d'), ('batch', 64), ('hp', 0), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
key = frozenset({('model_str', 'norm2d'), ('batch', 64), ('hp', 0), ('nodes', 2), ('numf', 32)})

tor[key].sort_values(by='CPU total (us)', ascending=False)

# %%
tf = load('profiling/results/data_1.tflow')

# %%
key = frozenset({('model_str', 'norm1d'), ('batch', 64), ('hp', 0), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'norm2d'), ('batch', 64), ('hp', 0), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'conv1d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'conv2d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'avg1d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'avg2d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

dt=tf[key][['Type', 'Total self-time (us)']].groupby(by='Type').sum()
dt=dt.reset_index()
dt.columns=['type', 'time']
dt['time']=dt['time']/1000
dt.sort_values(by='time', ascending=False)

# %%
key = frozenset({('model_str', 'avg2d'), ('batch', 64), ('hp', 4), ('nodes', 2), ('numf', 32)})

dt=tf[key]
dt.sort_values(by='Total self-time (us)')

# %%
key = frozenset({('model_str', 'conv2d'), ('batch', 32), ('hp', 4), ('nodes', 1), ('numf', 32)})

dt=tf[key]

dt = dt.sort_values(by='Total time (us)', ascending=False)
dt
# Out:
#                              Type  \
# 40                           IDLE
# 101                  _FusedConv2D
# 24           Conv2DBackpropFilter
# 15                    BiasAddGrad
# 60                OptimizeDataset
# 25                        Dataset
# 26                        Dataset
# 48                         MatMul
# 27                        Dataset
# 23                           Cast
# 80                       ReluGrad
# 47                         MatMul
# 102                  _FusedMatMul
# 85                       SelectV2
# 75                        RealDiv
# 77                        RealDiv
# 83   ResourceApplyGradientDescent
# 42                IteratorGetNext
# 81   ResourceApplyGradientDescent
# 82   ResourceApplyGradientDescent
# 4                          ArgMax
# 59                            Neg
# 17                    BroadcastTo
# 18                    BroadcastTo
# 86                       SelectV2
# 84   ResourceApplyGradientDescent
# ...

# %%
dt = dt[dt['Operation']!='IDLE']
dt
# Out:
#                              Type  \
# 101                  _FusedConv2D
# 24           Conv2DBackpropFilter
# 15                    BiasAddGrad
# 60                OptimizeDataset
# 25                        Dataset
# 26                        Dataset
# 48                         MatMul
# 27                        Dataset
# 23                           Cast
# 80                       ReluGrad
# 47                         MatMul
# 102                  _FusedMatMul
# 85                       SelectV2
# 75                        RealDiv
# 77                        RealDiv
# 83   ResourceApplyGradientDescent
# 42                IteratorGetNext
# 81   ResourceApplyGradientDescent
# 82   ResourceApplyGradientDescent
# 4                          ArgMax
# 59                            Neg
# 17                    BroadcastTo
# 18                    BroadcastTo
# 86                       SelectV2
# 84   ResourceApplyGradientDescent
# 87                   StridedSlice
# ...

# %%
total=dt['Total self-time (us)'].sum()

# %%
total*10**(-6)
# Out:
# 10.685954576

# %%
import profiling.models_tflow as m

M = m.conv2d(32,4)

M.create()

data = M.tf_data.batch(32)
model = M.model
# Out:
# This is tflow-conv2d

# %%
import time
start_time = time.time()
model.fit(data, epochs=10)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 2/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 3/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 4/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 5/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 6/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 7/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 8/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 9/10
# 157/157 [==============================] - 1s 4ms/step - loss: 9.2582 - accuracy: 0.1052
# Epoch 10/10
# ...
